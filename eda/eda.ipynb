# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df= pd.read_csv('../data/ProductionData/energie_opwek.csv')
df
# Out:
#             validfrom (UTC)        validto (UTC)      point           type  \
# 0       2020-12-31 23:00:00  2021-01-01 00:00:00  Nederland     WastePower
# 1       2021-01-01 00:00:00  2021-01-01 01:00:00  Nederland     WastePower
# 2       2021-01-01 01:00:00  2021-01-01 02:00:00  Nederland     WastePower
# 3       2021-01-01 02:00:00  2021-01-01 03:00:00  Nederland     WastePower
# 4       2021-01-01 03:00:00  2021-01-01 04:00:00  Nederland     WastePower
# ...                     ...                  ...        ...            ...
# 271579  2023-12-31 18:00:00  2023-12-31 19:00:00  Nederland  WindOffshoreC
# 271580  2023-12-31 19:00:00  2023-12-31 20:00:00  Nederland  WindOffshoreC
# 271581  2023-12-31 20:00:00  2023-12-31 21:00:00  Nederland  WindOffshoreC
# 271582  2023-12-31 21:00:00  2023-12-31 22:00:00  Nederland  WindOffshoreC
# 271583  2023-12-31 22:00:00  2023-12-31 23:00:00  Nederland  WindOffshoreC
#
# ...

# %%
df['type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>

# %%
df['activity'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='activity'>

# %%
df['classification'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='classification'>

# %%
# Sort by Type (optional, for better visualization)
df = df.sort_values(by='type')

# Plot the line graph
plt.plot(df['type'], df['emissionfactor (kg CO2/kWh)'], marker='o', color='b', label='Emission Factor')

# Add labels and title
plt.title('Emission Factors by Type')
plt.xlabel('Type')
plt.ylabel('Emission Factor')
plt.legend()

# Show the plot
plt.show()

# %%
# Drop rows where Type is 'wkk total'
df = df[df['type'] != 'WKK Total']

# Display the filtered DataFrame
df
# Out:
#             validfrom (UTC)        validto (UTC)      point           type  \
# 39418   2022-07-02 09:00:00  2022-07-02 10:00:00  Nederland   BiomassPower
# 35031   2021-12-31 14:00:00  2021-12-31 15:00:00  Nederland   BiomassPower
# 35032   2021-12-31 15:00:00  2021-12-31 16:00:00  Nederland   BiomassPower
# 35033   2021-12-31 16:00:00  2021-12-31 17:00:00  Nederland   BiomassPower
# 35034   2021-12-31 17:00:00  2021-12-31 18:00:00  Nederland   BiomassPower
# ...                     ...                  ...        ...            ...
# 230692  2019-05-03 03:00:00  2019-05-03 04:00:00  Nederland  WindOffshoreC
# 230693  2019-05-03 04:00:00  2019-05-03 05:00:00  Nederland  WindOffshoreC
# 230694  2019-05-03 05:00:00  2019-05-03 06:00:00  Nederland  WindOffshoreC
# 230682  2019-05-02 17:00:00  2019-05-02 18:00:00  Nederland  WindOffshoreC
# 271583  2023-12-31 22:00:00  2023-12-31 23:00:00  Nederland  WindOffshoreC
#
# ...

# %%
df['type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type'>
