# %% [markdown]
# # Solar Panels Data Cleaning
# This notebook will be used to clean the solar panel dataset.

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

print('Pandas version:', pd.__version__) # 2.2.3
print('Numpy version:', np.__version__) # 1.26.4
# Out:
# Pandas version: 2.2.3
# Numpy version: 1.26.4

# %% [markdown]
# # Load the dataset
# The dataset was downloaded from <a href='https://opendata.cbs.nl/#/CBS/nl/dataset/85005NED/table'>cbs</a>. It contains the amount of solar panels in the Netherlands at the end of the years 2021, 2022 and 2023.

# %%
df = pd.read_csv('../data/Other/Zonnepanelen_2021-2024.csv', sep=';', skiprows=3)
df
# Out:
#                           Regio's                            Onderwerp  \
# 0                       Nederland                         Installaties
# 1                       Nederland  Opgesteld vermogen van zonnepanelen
# 2                       Nederland         Opgesteld vermogen omvormers
# 3                       Nederland            Productie van zonnestroom
# 4            Noord-Nederland (LD)                         Installaties
# ...                           ...                                  ...
# 1516  Gemeenten; niet in te delen                         Installaties
# 1517  Gemeenten; niet in te delen  Opgesteld vermogen van zonnepanelen
# 1518  Gemeenten; niet in te delen         Opgesteld vermogen omvormers
# 1519  Gemeenten; niet in te delen            Productie van zonnestroom
# 1520                    Bron: CBS                                  NaN
#
#      Unnamed: 2     2021       2022   2023 ** 2024 eerste helft*
# 0        aantal   1730285   2298859   2875487            3023653
# 1           kWp  14822880  19536096  24301725           26065113
# 2            kW       NaN  17451365  21394768           22814464
# 3       mln kWh     11304     16659     19580              10984
# 4        aantal    246365    309909    379524             398051
# ...         ...       ...       ...       ...                ...
# 1516     aantal       426       509       520                533
# 1517        kWp     14389     17208     28679             175854
# 1518         kW       NaN     14768     23689             140124
# 1519    mln kWh        12        16        25                 28
# 1520        NaN       NaN       NaN       NaN                NaN
#
# [1521 rows x 7 columns]

# %% [markdown]
# # Data Cleaning
# First we will drop the last row, since this does not contain any data but just states the source.

# %%
if df["Regio's"].iloc[-1] == 'Bron: CBS':
    df = df.drop(index=df.index[-1])

df.tail(5)
# Out:
#                           Regio's                            Onderwerp  \
# 1515                       Zwolle            Productie van zonnestroom
# 1516  Gemeenten; niet in te delen                         Installaties
# 1517  Gemeenten; niet in te delen  Opgesteld vermogen van zonnepanelen
# 1518  Gemeenten; niet in te delen         Opgesteld vermogen omvormers
# 1519  Gemeenten; niet in te delen            Productie van zonnestroom
#
#      Unnamed: 2  2021    2022 2023 ** 2024 eerste helft*
# 1515    mln kWh      .      .       .                  .
# 1516     aantal    426    509     520                533
# 1517        kWp  14389  17208   28679             175854
# 1518         kW    NaN  14768   23689             140124
# 1519    mln kWh     12     16      25                 28

# %% [markdown]
# Next we will drop the unnamed column, as this column is not necessary.

# %%
df = df.drop(columns=['Unnamed: 2'])
df.head()
# Out:
#                 Regio's                            Onderwerp     2021   \
# 0             Nederland                         Installaties   1730285
# 1             Nederland  Opgesteld vermogen van zonnepanelen  14822880
# 2             Nederland         Opgesteld vermogen omvormers       NaN
# 3             Nederland            Productie van zonnestroom     11304
# 4  Noord-Nederland (LD)                         Installaties    246365
#
#        2022   2023 ** 2024 eerste helft*
# 0   2298859   2875487            3023653
# 1  19536096  24301725           26065113
# 2  17451365  21394768           22814464
# 3     16659     19580              10984
# 4    309909    379524             398051

# %% [markdown]
# We will also rename the year columns to only contain the year and no other characters.

# %%
df = df.rename(columns={'2023 **': '2023', '2024 eerste helft*': '2024'})
df.head()
# Out:
#                 Regio's                            Onderwerp     2021   \
# 0             Nederland                         Installaties   1730285
# 1             Nederland  Opgesteld vermogen van zonnepanelen  14822880
# 2             Nederland         Opgesteld vermogen omvormers       NaN
# 3             Nederland            Productie van zonnestroom     11304
# 4  Noord-Nederland (LD)                         Installaties    246365
#
#        2022      2023      2024
# 0   2298859   2875487   3023653
# 1  19536096  24301725  26065113
# 2  17451365  21394768  22814464
# 3     16659     19580     10984
# 4    309909    379524    398051

# %% [markdown]
# Finally we will change the format of the dataframe from a wide format to a long format, by switching the `Onderwerp` values with the years.

# %%
df_long = pd.melt(df, id_vars=["Regio's", 'Onderwerp'], var_name='Year', value_name='Value')

df_long['Value'] = df_long['Value'].replace('.', np.nan)
df_long['Value'] = pd.to_numeric(df_long['Value'], errors='coerce')

# %%
df_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6080 entries, 0 to 6079
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Regio's    6080 non-null   object
#  1   Onderwerp  6080 non-null   object
#  2   Year       6080 non-null   object
#  3   Value      4091 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 190.1+ KB

# %% [markdown]
# We can see there are some null values in the `Value` column. </br>
# We will also check for duplicates before we pivot the dataframe.

# %%
duplicates = df_long[df_long.duplicated(subset=['Year', 'Onderwerp', "Regio's"], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Regio's, Onderwerp, Year, Value]
# Index: []

# %% [markdown]
# There appear to be no duplicate rows.

# %%
df_pivot = df_long.pivot(index=['Year', "Regio's"], columns='Onderwerp', values='Value').reset_index()
df_pivot.columns.name = None

df_pivot
# Out:
#        Year                   Regio's  Installaties  \
# 0     2021   's-Gravenhage (gemeente)       17989.0
# 1     2021           's-Hertogenbosch       13883.0
# 2     2021                Aa en Hunze        4392.0
# 3     2021                   Aalsmeer        3093.0
# 4     2021                     Aalten        3346.0
# ...     ...                       ...           ...
# 1515   2024                   Zundert        4548.0
# 1516   2024                   Zutphen        8238.0
# 1517   2024           Zwartewaterland        4620.0
# 1518   2024               Zwijndrecht        6638.0
# 1519   2024                    Zwolle       25337.0
#
#       Opgesteld vermogen omvormers  Opgesteld vermogen van zonnepanelen  \
# 0                              NaN                              77435.0
# 1                              NaN                             103745.0
# 2                              NaN                              33382.0
# 3                              NaN                              34473.0
# 4                              NaN                              33100.0
# ...                            ...                                  ...
# 1515                       39621.0                              45963.0
# 1516                       55888.0                              62270.0
# 1517                       37664.0                              41483.0
# 1518                      100421.0                             105131.0
# 1519                      177869.0                             203609.0
#
#       Productie van zonnestroom
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 1515                        NaN
# 1516                        NaN
# 1517                        NaN
# 1518                        NaN
# 1519                        NaN
#
# [1520 rows x 6 columns]

# %% [markdown]
# We can see there are a lot of null values in the `Productie van zonnestroom` column, let's look at all the null values.

# %%
df_pivot.isnull().sum()
# Out:
# Year                                      0
# Regio's                                   0
# Installaties                             59
# Opgesteld vermogen omvormers            431
# Opgesteld vermogen van zonnepanelen      59
# Productie van zonnestroom              1440
# dtype: int64

# %% [markdown]
# Most of the null values are in the columns `Productie van zonnestroom`, `Opgesteld vermogen omvormers` and `Opgesteld vermogen van zonnepanelen`. Since we will not be using the columns in this project it is not a big problem. However, there are 59 NaN values in the `Installaties` column. We have to see which are null.

# %%
# Identify rows where the 'Installaties' column is null
null_installaties_rows = df_pivot[df_pivot['Installaties'].isnull()]

# Display the rows
null_installaties_rows
# Out:
#        Year              Regio's  Installaties  Opgesteld vermogen omvormers  \
# 19    2021            Appingedam           NaN                           NaN
# 72    2021              Delfzijl           NaN                           NaN
# 77    2021         Dijk en Waard           NaN                           NaN
# 124   2021                Haaren           NaN                           NaN
# 171   2021        Land van Cuijk           NaN                           NaN
# 191   2021             Loppersum           NaN                           NaN
# 195   2021             Maashorst           NaN                           NaN
# 331   2021        Voorne aan Zee           NaN                           NaN
# 399    2022           Appingedam           NaN                           NaN
# 409    2022             Beemster           NaN                           NaN
# 429    2022              Boxmeer           NaN                           NaN
# 443    2022                Cuijk           NaN                           NaN
# 452    2022             Delfzijl           NaN                           NaN
# 499    2022                Grave           NaN                           NaN
# 504    2022               Haaren           NaN                           NaN
# 517    2022        Heerhugowaard           NaN                           NaN
# 552    2022              Landerd           NaN                           NaN
# 555    2022            Langedijk           NaN                           NaN
# 571    2022            Loppersum           NaN                           NaN
# 586    2022  Mill en Sint Hubert           NaN                           NaN
# 661    2022        Sint Anthonis           NaN                           NaN
# 689    2022                 Uden           NaN                           NaN
# 711    2022       Voorne aan Zee           NaN                           NaN
# 779    2023           Appingedam           NaN                           NaN
# 789    2023             Beemster           NaN                           NaN
# 809    2023              Boxmeer           NaN                           NaN
# 812    2023              Brielle           NaN                           NaN
# 823    2023                Cuijk           NaN                           NaN
# 832    2023             Delfzijl           NaN                           NaN
# 879    2023                Grave           NaN                           NaN
# 884    2023               Haaren           NaN                           NaN
# 897    2023        Heerhugowaard           NaN                           NaN
# 902    2023       Hellevoetsluis           NaN                           NaN
# 932    2023              Landerd           NaN                           NaN
# 935    2023            Langedijk           NaN                           NaN
# 951    2023            Loppersum           NaN                           NaN
# 966    2023  Mill en Sint Hubert           NaN                           NaN
# 1041   2023        Sint Anthonis           NaN                           NaN
# 1069   2023                 Uden           NaN                           NaN
# 1103   2023                Weesp           NaN                           NaN
# 1113   2023           Westvoorne           NaN                           NaN
# 1159   2024           Appingedam           NaN                           NaN
# 1169   2024             Beemster           NaN                           NaN
# 1189   2024              Boxmeer           NaN                           NaN
# 1192   2024              Brielle           NaN                           NaN
# 1203   2024                Cuijk           NaN                           NaN
# 1212   2024             Delfzijl           NaN                           NaN
# 1259   2024                Grave           NaN                           NaN
# 1264   2024               Haaren           NaN                           NaN
# 1277   2024        Heerhugowaard           NaN                           NaN
# 1282   2024       Hellevoetsluis           NaN                           NaN
# 1312   2024              Landerd           NaN                           NaN
# 1315   2024            Langedijk           NaN                           NaN
# 1331   2024            Loppersum           NaN                           NaN
# 1346   2024  Mill en Sint Hubert           NaN                           NaN
# 1421   2024        Sint Anthonis           NaN                           NaN
# 1449   2024                 Uden           NaN                           NaN
# 1483   2024                Weesp           NaN                           NaN
# 1493   2024           Westvoorne           NaN                           NaN
#
#       Opgesteld vermogen van zonnepanelen  Productie van zonnestroom
# 19                                    NaN                        NaN
# 72                                    NaN                        NaN
# 77                                    NaN                        NaN
# 124                                   NaN                        NaN
# 171                                   NaN                        NaN
# 191                                   NaN                        NaN
# 195                                   NaN                        NaN
# 331                                   NaN                        NaN
# 399                                   NaN                        NaN
# 409                                   NaN                        NaN
# 429                                   NaN                        NaN
# 443                                   NaN                        NaN
# 452                                   NaN                        NaN
# 499                                   NaN                        NaN
# 504                                   NaN                        NaN
# 517                                   NaN                        NaN
# 552                                   NaN                        NaN
# 555                                   NaN                        NaN
# 571                                   NaN                        NaN
# 586                                   NaN                        NaN
# 661                                   NaN                        NaN
# 689                                   NaN                        NaN
# 711                                   NaN                        NaN
# 779                                   NaN                        NaN
# 789                                   NaN                        NaN
# 809                                   NaN                        NaN
# 812                                   NaN                        NaN
# 823                                   NaN                        NaN
# 832                                   NaN                        NaN
# 879                                   NaN                        NaN
# 884                                   NaN                        NaN
# 897                                   NaN                        NaN
# 902                                   NaN                        NaN
# 932                                   NaN                        NaN
# 935                                   NaN                        NaN
# 951                                   NaN                        NaN
# 966                                   NaN                        NaN
# 1041                                  NaN                        NaN
# 1069                                  NaN                        NaN
# 1103                                  NaN                        NaN
# 1113                                  NaN                        NaN
# 1159                                  NaN                        NaN
# 1169                                  NaN                        NaN
# 1189                                  NaN                        NaN
# 1192                                  NaN                        NaN
# 1203                                  NaN                        NaN
# 1212                                  NaN                        NaN
# 1259                                  NaN                        NaN
# 1264                                  NaN                        NaN
# 1277                                  NaN                        NaN
# 1282                                  NaN                        NaN
# 1312                                  NaN                        NaN
# 1315                                  NaN                        NaN
# 1331                                  NaN                        NaN
# 1346                                  NaN                        NaN
# 1421                                  NaN                        NaN
# 1449                                  NaN                        NaN
# 1483                                  NaN                        NaN
# 1493                                  NaN                        NaN

# %% [markdown]
# We can see none of the rows have any values in them. For this reason we will drop them, because there is not way to fill them in.

# %%
df_pivot = df_pivot[df_pivot['Installaties'].notnull()]

df_pivot.reset_index(drop=True, inplace=True)

# %%
df_pivot.isnull().sum()
# Out:
# Year                                      0
# Regio's                                   0
# Installaties                              0
# Opgesteld vermogen omvormers            372
# Opgesteld vermogen van zonnepanelen       0
# Productie van zonnestroom              1381
# dtype: int64

# %% [markdown]
# Finally we will export the cleaned dataframe, so we can use it for further analysis.

# %%
file_path = '../data/Other/cleaned_solar_panel_data.csv'
df_pivot.to_csv(file_path, index=False)
