# %% [markdown]
# # Production Data Cleaning

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Loading Data
#
# The Data used in this notebook is from
# > https://ned.nl/

# %%
df = pd.read_csv('../data/ProductionData/energie_opwek.csv')
df
# Out:
#             validfrom (UTC)        validto (UTC)      point           type  \
# 0       2020-12-31 23:00:00  2021-01-01 00:00:00  Nederland     WastePower
# 1       2021-01-01 00:00:00  2021-01-01 01:00:00  Nederland     WastePower
# 2       2021-01-01 01:00:00  2021-01-01 02:00:00  Nederland     WastePower
# 3       2021-01-01 02:00:00  2021-01-01 03:00:00  Nederland     WastePower
# 4       2021-01-01 03:00:00  2021-01-01 04:00:00  Nederland     WastePower
# ...                     ...                  ...        ...            ...
# 271579  2023-12-31 18:00:00  2023-12-31 19:00:00  Nederland  WindOffshoreC
# 271580  2023-12-31 19:00:00  2023-12-31 20:00:00  Nederland  WindOffshoreC
# 271581  2023-12-31 20:00:00  2023-12-31 21:00:00  Nederland  WindOffshoreC
# 271582  2023-12-31 21:00:00  2023-12-31 22:00:00  Nederland  WindOffshoreC
# 271583  2023-12-31 22:00:00  2023-12-31 23:00:00  Nederland  WindOffshoreC
#
#        granularity timezone   activity classification  capacity (kW)  \
# 0             Hour      UTC  Providing        Current         418750
# 1             Hour      UTC  Providing        Current         416000
# 2             Hour      UTC  Providing        Current         430250
# 3             Hour      UTC  Providing        Current         436750
# 4             Hour      UTC  Providing        Current         436000
# ...            ...      ...        ...            ...            ...
# 271579        Hour      UTC  Providing        Current        3144000
# 271580        Hour      UTC  Providing        Current        3102250
# 271581        Hour      UTC  Providing        Current        3086249
# 271582        Hour      UTC  Providing        Current        3051749
# 271583        Hour      UTC  Providing        Current        3074000
#
#         volume (kWh)  percentage  emission (kg CO2)  \
# 0             418750    0.536859             125625
# 1             416000    0.533333             124800
# 2             430250    0.551602             129075
# 3             436750    0.559936             131025
# 4             436000    0.558974             130800
# ...              ...         ...                ...
# 271579       3144000    1.431400                  0
# 271580       3102250    1.412392                  0
# 271581       3086249    1.405107                  0
# 271582       3051749    1.389403                  0
# 271583       3074000    1.399530                  0
#
#         emissionfactor (kg CO2/kWh)
# 0                               0.3
# 1                               0.3
# 2                               0.3
# 3                               0.3
# 4                               0.3
# ...                             ...
# 271579                          0.0
# 271580                          0.0
# 271581                          0.0
# 271582                          0.0
# 271583                          0.0
#
# [271584 rows x 13 columns]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# To start of the data cleaning process i printed the head of the dataframe to see what needs to be cleaned at first glance.

# %%
df
# Out:
#             validfrom (UTC)        validto (UTC)      point           type  \
# 0       2020-12-31 23:00:00  2021-01-01 00:00:00  Nederland     WastePower
# 1       2021-01-01 00:00:00  2021-01-01 01:00:00  Nederland     WastePower
# 2       2021-01-01 01:00:00  2021-01-01 02:00:00  Nederland     WastePower
# 3       2021-01-01 02:00:00  2021-01-01 03:00:00  Nederland     WastePower
# 4       2021-01-01 03:00:00  2021-01-01 04:00:00  Nederland     WastePower
# ...                     ...                  ...        ...            ...
# 271579  2023-12-31 18:00:00  2023-12-31 19:00:00  Nederland  WindOffshoreC
# 271580  2023-12-31 19:00:00  2023-12-31 20:00:00  Nederland  WindOffshoreC
# 271581  2023-12-31 20:00:00  2023-12-31 21:00:00  Nederland  WindOffshoreC
# 271582  2023-12-31 21:00:00  2023-12-31 22:00:00  Nederland  WindOffshoreC
# 271583  2023-12-31 22:00:00  2023-12-31 23:00:00  Nederland  WindOffshoreC
#
#        granularity timezone   activity classification  capacity (kW)  \
# 0             Hour      UTC  Providing        Current         418750
# 1             Hour      UTC  Providing        Current         416000
# 2             Hour      UTC  Providing        Current         430250
# 3             Hour      UTC  Providing        Current         436750
# 4             Hour      UTC  Providing        Current         436000
# ...            ...      ...        ...            ...            ...
# 271579        Hour      UTC  Providing        Current        3144000
# 271580        Hour      UTC  Providing        Current        3102250
# 271581        Hour      UTC  Providing        Current        3086249
# 271582        Hour      UTC  Providing        Current        3051749
# 271583        Hour      UTC  Providing        Current        3074000
#
#         volume (kWh)  percentage  emission (kg CO2)  \
# 0             418750    0.536859             125625
# 1             416000    0.533333             124800
# 2             430250    0.551602             129075
# 3             436750    0.559936             131025
# 4             436000    0.558974             130800
# ...              ...         ...                ...
# 271579       3144000    1.431400                  0
# 271580       3102250    1.412392                  0
# 271581       3086249    1.405107                  0
# 271582       3051749    1.389403                  0
# 271583       3074000    1.399530                  0
#
#         emissionfactor (kg CO2/kWh)
# 0                               0.3
# 1                               0.3
# 2                               0.3
# 3                               0.3
# 4                               0.3
# ...                             ...
# 271579                          0.0
# 271580                          0.0
# 271581                          0.0
# 271582                          0.0
# 271583                          0.0
#
# [271584 rows x 13 columns]

# %% [markdown]
# From the data above i can see there are a couple of columns where I should remove the measurement scale.

# %%
# Rename columns
df.rename(columns={
    'capacity (kW)': 'capacity',
    'volume (kWh)': 'volume',
    'emission (kg CO2)': 'emission',
    'emissionfactor (kg CO2/kWh)': 'emissionfactor'
}, inplace=True)
df
# Out:
#             validfrom (UTC)        validto (UTC)      point           type  \
# 0       2020-12-31 23:00:00  2021-01-01 00:00:00  Nederland     WastePower
# 1       2021-01-01 00:00:00  2021-01-01 01:00:00  Nederland     WastePower
# 2       2021-01-01 01:00:00  2021-01-01 02:00:00  Nederland     WastePower
# 3       2021-01-01 02:00:00  2021-01-01 03:00:00  Nederland     WastePower
# 4       2021-01-01 03:00:00  2021-01-01 04:00:00  Nederland     WastePower
# ...                     ...                  ...        ...            ...
# 271579  2023-12-31 18:00:00  2023-12-31 19:00:00  Nederland  WindOffshoreC
# 271580  2023-12-31 19:00:00  2023-12-31 20:00:00  Nederland  WindOffshoreC
# 271581  2023-12-31 20:00:00  2023-12-31 21:00:00  Nederland  WindOffshoreC
# 271582  2023-12-31 21:00:00  2023-12-31 22:00:00  Nederland  WindOffshoreC
# 271583  2023-12-31 22:00:00  2023-12-31 23:00:00  Nederland  WindOffshoreC
#
#        granularity timezone   activity classification  capacity   volume  \
# 0             Hour      UTC  Providing        Current    418750   418750
# 1             Hour      UTC  Providing        Current    416000   416000
# 2             Hour      UTC  Providing        Current    430250   430250
# 3             Hour      UTC  Providing        Current    436750   436750
# 4             Hour      UTC  Providing        Current    436000   436000
# ...            ...      ...        ...            ...       ...      ...
# 271579        Hour      UTC  Providing        Current   3144000  3144000
# 271580        Hour      UTC  Providing        Current   3102250  3102250
# 271581        Hour      UTC  Providing        Current   3086249  3086249
# 271582        Hour      UTC  Providing        Current   3051749  3051749
# 271583        Hour      UTC  Providing        Current   3074000  3074000
#
#         percentage  emission  emissionfactor
# 0         0.536859    125625             0.3
# 1         0.533333    124800             0.3
# 2         0.551602    129075             0.3
# 3         0.559936    131025             0.3
# 4         0.558974    130800             0.3
# ...            ...       ...             ...
# 271579    1.431400         0             0.0
# 271580    1.412392         0             0.0
# 271581    1.405107         0             0.0
# 271582    1.389403         0             0.0
# 271583    1.399530         0             0.0
#
# [271584 rows x 13 columns]

# %% [markdown]
# After changing the column names to a more understandable name, it is time to look at the information about the dataframe.
# I left the valid from and valid to out since we only need one of the columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271584 entries, 0 to 271583
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   validfrom (UTC)  271584 non-null  object
#  1   validto (UTC)    271584 non-null  object
#  2   point            271584 non-null  object
#  3   type             271584 non-null  object
#  4   granularity      271584 non-null  object
#  5   timezone         271584 non-null  object
#  6   activity         271584 non-null  object
#  7   classification   271584 non-null  object
#  8   capacity         271584 non-null  int64
#  9   volume           271584 non-null  int64
#  10  percentage       271584 non-null  float64
#  11  emission         271584 non-null  int64
#  12  emissionfactor   271584 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 26.9+ MB

# %% [markdown]
# Here it is visable that the valid from and valid to is not a datetime type but an object type, so we will fix that in the next code cell.

# %%
df['datetime'] = pd.to_datetime(df['validfrom (UTC)'])

# Drop unnecessary columns
df.drop(columns=['validfrom (UTC)', 'validto (UTC)'], inplace=True)

# Reorder columns
cols = ['datetime'] + [col for col in df if col != 'datetime']
df = df[cols]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271584 entries, 0 to 271583
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   datetime        271584 non-null  datetime64[ns]
#  1   point           271584 non-null  object
#  2   type            271584 non-null  object
#  3   granularity     271584 non-null  object
#  4   timezone        271584 non-null  object
#  5   activity        271584 non-null  object
#  6   classification  271584 non-null  object
#  7   capacity        271584 non-null  int64
#  8   volume          271584 non-null  int64
#  9   percentage      271584 non-null  float64
#  10  emission        271584 non-null  int64
#  11  emissionfactor  271584 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 24.9+ MB

# %% [markdown]
# We also removed the valid to column and changed the valid from column to datetime. This column represents the time that the measuring started.
#
# The next step is to look if there are any NAN values in the data.

# %%
df.isnull().sum()
# Out:
# datetime          0
# point             0
# type              0
# granularity       0
# timezone          0
# activity          0
# classification    0
# capacity          0
# volume            0
# percentage        0
# emission          0
# emissionfactor    0
# dtype: int64

# %% [markdown]
# There are no NAN values in the dataset, so we can export this data to a cleaned csv file.
#
# When working on the data, there was data from 2016 in the production dataset. To ensure that we only have data from 2021 and later, we remove the older data here.

# %%
df = df[df['datetime'].dt.year >= 2021]
df
# Out:
#                   datetime      point           type granularity timezone  \
# 1      2021-01-01 00:00:00  Nederland     WastePower        Hour      UTC
# 2      2021-01-01 01:00:00  Nederland     WastePower        Hour      UTC
# 3      2021-01-01 02:00:00  Nederland     WastePower        Hour      UTC
# 4      2021-01-01 03:00:00  Nederland     WastePower        Hour      UTC
# 5      2021-01-01 04:00:00  Nederland     WastePower        Hour      UTC
# ...                    ...        ...            ...         ...      ...
# 271579 2023-12-31 18:00:00  Nederland  WindOffshoreC        Hour      UTC
# 271580 2023-12-31 19:00:00  Nederland  WindOffshoreC        Hour      UTC
# 271581 2023-12-31 20:00:00  Nederland  WindOffshoreC        Hour      UTC
# 271582 2023-12-31 21:00:00  Nederland  WindOffshoreC        Hour      UTC
# 271583 2023-12-31 22:00:00  Nederland  WindOffshoreC        Hour      UTC
#
#          activity classification  capacity   volume  percentage  emission  \
# 1       Providing        Current    416000   416000    0.533333    124800
# 2       Providing        Current    430250   430250    0.551602    129075
# 3       Providing        Current    436750   436750    0.559936    131025
# 4       Providing        Current    436000   436000    0.558974    130800
# 5       Providing        Current    435500   435500    0.558333    130650
# ...           ...            ...       ...      ...         ...       ...
# 271579  Providing        Current   3144000  3144000    1.431400         0
# 271580  Providing        Current   3102250  3102250    1.412392         0
# 271581  Providing        Current   3086249  3086249    1.405107         0
# 271582  Providing        Current   3051749  3051749    1.389403         0
# 271583  Providing        Current   3074000  3074000    1.399530         0
#
#         emissionfactor
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# 5                  0.3
# ...                ...
# 271579             0.0
# 271580             0.0
# 271581             0.0
# 271582             0.0
# 271583             0.0
#
# [236511 rows x 12 columns]

# %% [markdown]
# Converting the dataframe to a CSV file so we can use it in the next steps of the project.

# %%
df.to_csv('../data/ProductionData/cleaned_energie_opwek.csv', index=False)
